# %% [markdown]
# <a href="https://colab.research.google.com/github/khrwnnn/CPE009A-CPE12S2/blob/main/Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if 5>2:
  print("Five is greater than Two!")
# Out:
# Five is greater than Two!

# %% [markdown]
# Python Comments

# %%
#This is a comment
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# Python Variable

# %%
x = 1
a, b = 0,-1
a, b, c = 0,-1, 2

b = "Sally" #This is a type of string
print(b)
# Out:
# Sally

# %% [markdown]
# Casting

# %%
b = "sally" #This is a type of string
b = int(4)
print(b)

b = float(4)
print(b)
# Out:
# 4
# 4.0

# %% [markdown]
# Type() function

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# "Double quotes" or 'Single' Quotes

# %%
y = "John"
y = 'John'

# %% [markdown]
# Case Sensitive

# %%
a = 4
A = "Sally"
#A will not overwrite a

# %% [markdown]
# Multiple Variables

# %%
x, y, z = "one", "two", "three"
print(x)
print(y)
print(z)
# Out:
# one
# two
# three

# %% [markdown]
# One Value to Multiple Variables

# %%
x = y = z = "four"
print(x)
print(y)
print(z)
# Out:
# four
# four
# four

# %% [markdown]
# Output Variables

# %%
x = "enjoying"
print("Python programming is " + x)
# Out:
# Python programming is enjoying

# %% [markdown]
# Output Variables Other way

# %%
x = "Python is "
y = "enjoying"
z = x + y
print(z)
# Out:
# Python is enjoying

# %% [markdown]
# Arithmetic Operations

# %%
x = 5
y = -3
print(x+y)

x = 5
y = 3
sum =  x+y
sum


x = 10
y = 5
print(x*y)

x = 5
y = 10
print(x-y)


x = 10
y = 10
print(x/y)

x = 10
y = 3
print(x%y)

x = 10
y = 10
print(x%y)
# Out:
# 2
# 50
# -5
# 1.0
# 1
# 0

# %% [markdown]
# Assignment Operators

# %%
s = 1
s+=3
print(s)

s = 1
s-=3
print(s)

s = 1
s*=3
print(s)

s = 1
s/=3
print(s)

s = 1
s%=3
print(s)
# Out:
# 4
# -2
# 3
# 0.3333333333333333
# 1

# %% [markdown]
# Comparison Operators

# %%
t = 1
u = 2
t>u
t<u
t>=u
t<=u
t==u
t!=u
# Out:
# True

# %% [markdown]
# Logical Operators

# %%
t < 5 and u < 10
# Out:
# True

# %%
t < 5 or u < 10
# Out:
# True

# %%
not (t < 5 or u < 10)
# Out:
# False

# %%
t is u
# Out:
# False

# %%
t is not u
# Out:
# True

# %% [markdown]
# Bitwise Operators

# %%
v = 2
v << 1
v << 2
# Out:
# 8

# %%
t & u
# Out:
# 0

# %%
15 & 15
# Out:
# 15
